# %% [markdown]
# ## Composite Weekly trends plot for different years
# * resampling frequency is 2 Days
# * composition of the "Mean" and the "Median" of weekly trends for different years
# * various rates of the chlor-a concentration
# * "fixed scale" seems more illustrative than the "min-max scale"

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import xarray as xr
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime
import datetime

# %%
# load the floats data 
# ********************
# *** CSV files ***
# ********************
# load CSV output    
#plt = plt.figure(8,6)
plt.close('all')
plt.cla()  # axis
plt.clf()  # figure
plt.show()

freq = 4
pref = 'df_chl_dist_out_'
surf =  '_modisa.csv'
infile = pref + str(freq) + 'D' + surf

folder = '../data_collector_modisa_chla9km/df_multidimInterpolation/'
direc = folder + infile
direc

print('in_filename and path:', direc)

df_tmp = pd.read_csv(direc, index_col='index')
df_tmp.sort_values(['id', 'time'])[:20]
# Out:
# in_filename and path: ../data_collector_modisa_chla9km/df_multidimInterpolation/df_chl_dist_out_4D_modisa.csv
#              time     id      var_tmp       temp   var_lon        lat  \
# index
# 1      2002-11-01  10206  1000.000000        NaN  0.000748  10.777875
# 260    2002-11-05  10206  1000.000000        NaN  0.001244  10.969438
# 519    2002-11-09  10206  1000.000000        NaN  0.001970  11.142188
# 778    2002-11-13  10206  1000.000000        NaN  0.005131  11.169250
# 1555   2002-11-25  10206  1000.000000        NaN  0.004529  11.268187
# 1814   2002-11-29  10206  1000.000000        NaN  0.001644  11.352438
# 2591   2002-12-11  10206  1000.000000        NaN  0.009155  11.990125
# 2850   2002-12-15  10206  1000.000000        NaN  0.002025  12.199438
# 3109   2002-12-19  10206  1000.000000        NaN  0.005358  12.357437
# 3368   2002-12-23  10206  1000.000000        NaN  0.003026  12.512187
# 3627   2002-12-27  10206  1000.000000        NaN  0.001646  12.586125
# 3886   2002-12-31  10206  1000.000000        NaN  0.000777  12.512063
# 4145   2003-01-04  10206  1000.000000        NaN  0.001778  12.361750
# 4922   2003-01-16  10206  1000.000000        NaN  0.004173  11.722875
# 5181   2003-01-20  10206  1000.000000        NaN  0.003313  11.382562
# 5440   2003-01-24  10206  1000.000000        NaN  0.002796  11.127937
# 5699   2003-01-28  10206  1000.000000        NaN  0.001431  10.962500
# 3      2002-11-01  11089     0.003694  29.023187  0.000111  14.205563
# 262    2002-11-05  11089     0.003664  28.916438  0.000101  14.332875
# 521    2002-11-09  11089     0.004114  28.998500  0.000147  14.321875
#
#              lon   var_lat         vn        spd     ...      chlor_a_log_e  \
# index                                                ...
# 1      67.455813  0.000284   6.842812  10.732500     ...          -2.049576
# 260    67.246562  0.000420   6.176937  11.645312     ...          -1.958975
# 519    67.122750  0.000627   2.215375   3.775187     ...          -2.033770
# 778    67.093687  0.001342   0.910313   3.080938     ...          -1.961023
# 1555   66.974625  0.001236   2.616437   3.502562     ...          -2.021816
# 1814   66.800250  0.000518   2.887438  10.056125     ...          -1.959905
# 2591   65.572500  0.002218   7.323000  13.708125     ...          -1.971186
# 2850   65.269813  0.000620   5.992188  10.612625     ...          -2.029819
# 3109   65.027500  0.001425   5.018875   9.448500     ...          -1.868672
# 3368   64.766250  0.000855   4.094062   9.786375     ...          -1.853966
# 3627   64.445063  0.000541   0.181000  11.005313     ...          -1.839380
# 3886   64.097000  0.000294  -3.712000  13.497563     ...          -1.697012
# 4145   63.734687  0.000573  -6.091938  12.489937     ...          -1.549859
# 4922   62.683750  0.001208 -11.447938  13.855813     ...          -0.972189
# 5181   62.413250  0.000949  -9.342625  13.077563     ...          -1.294643
# 5440   62.133063  0.000830  -7.864813  12.694125     ...          -1.289526
# 5699   61.932000  0.000514 -13.636000  20.937000     ...          -1.814501
# 3      65.260000  0.000059   5.290375  13.014187     ...          -1.987369
# 262    64.938312  0.000055   3.385312  14.344625     ...          -1.786916
# 521    64.466188  0.000073  -3.502250  17.239313     ...          -1.579820
#
#        chl_rate  chl_log_e_rate  chl_rate_stand  chl_log_e_rate_stand  \
# index
# 1      0.000609        0.004774       -0.000771              0.045827
# 260    0.003053        0.022650        0.001971              0.177362
# 519   -0.002540       -0.018699       -0.004304             -0.126880
# 778    0.002468        0.018187        0.001315              0.144521
# 1555  -0.002031       -0.014883       -0.003732             -0.098803
# 1814   0.002114        0.015478        0.000918              0.124588
# 2591   0.000923        0.006719       -0.000418              0.060138
# 2850  -0.001983       -0.014658       -0.003679             -0.097149
# 3109   0.005742        0.040287        0.004987              0.307129
# 3368   0.000572        0.003676       -0.000813              0.037755
# 3627   0.000575        0.003646       -0.000809              0.037533
# 3886   0.006079        0.035592        0.005365              0.272586
# 4145   0.007262        0.036788        0.006692              0.281388
# 4922   0.025588        0.078880        0.027249              0.591094
# 5181  -0.026065       -0.080613       -0.030692             -0.582440
# 5440   0.000351        0.001279       -0.001060              0.020116
# 5699  -0.028121       -0.131244       -0.032999             -0.954972
# 3      0.002345        0.017726        0.001177              0.141132
# 262    0.007605        0.050113        0.007077              0.379432
# 521    0.009634        0.051774        0.009353              0.391650
#
#        chl_rate_week  chl_log_e_rate_week  week  week_rotate        dist
# index
# 1           0.004263             0.033415    44            1  508.560212
# 260         0.021373             0.158552    45            2  529.832709
# 519        -0.017783            -0.130891    45            2  542.709123
# 778         0.017278             0.127308    46            3  545.846264
# 1555       -0.014214            -0.104180    48            5  558.839157
# 1814        0.014800             0.108345    48            5  578.029512
# 2591        0.006464             0.047030    50            7  716.594985
# 2850       -0.013881            -0.102607    50            7  752.201866
# 3109        0.040196             0.282007    51            8  780.835258
# 3368        0.004001             0.025735    52            9  811.630601
# 3627        0.004027             0.025525    52            9  847.416106
# 3886        0.042550             0.249144     1           11  883.429374
# 4145        0.050834             0.257519     1           11  920.112650
# 4922        0.179116             0.552160     3           13  890.889529
# 5181       -0.182452            -0.564294     4           14  866.877957
# 5440        0.002460             0.008955     4           14  841.844880
# 5699       -0.196844            -0.918706     5           15  824.233600
# 3           0.016417             0.124084    44            1  804.459653
# 262         0.053236             0.350794    45            2  841.899169
# 521         0.067438             0.362418    45            2  875.780163
#
# [20 rows x 22 columns]

# %%
df_tmp['time'] = pd.to_datetime(df_tmp['time']) # ,format='%m/%d/%y %I:%M%p'
df_timed = df_tmp.set_index('time')
# add a new column to the dataset
df_timed['year'] = df_timed.index.year
df_timed[:20]

year_max = df_timed.index.year.max()
year_min = df_timed.index.year.min()
print('year_max', year_max)
print('year_min', year_min)
#print(df_timed)
# Out:
# year_max 2016
# year_min 2002

# %%
### Part 1: Plot for the mean of the weekly trends
### Mean
start = year_min
for i in range(0,3):
    #plt.subplot(311+i)
    plt.figure(figsize=(8,6))
    plt.title("mean of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].mean().plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )

    start = start + 5
    axes1.set_ylim(-10, 10)
    #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
    plt.xlabel('week', fontsize=10)
    plt.ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)
    plt.yticks(np.arange(-12, 14, 2))
    plt.xticks(np.arange(1, 25, 1))

    axes1.legend(bbox_to_anchor=(1.15, 1.05))
    #plt.savefig(str(freq)+"D_weekly_mean_" + str(i) +".pdf")
    plt.show()
    
    plt.close()

# %%
### Part 1: Plot for the mean of the weekly trends
### Mean
### using subplots
# recommended approach
# http://stackoverflow.com/questions/6963035/pyplot-axes-labels-for-subplots

def plot_here(ax, start):
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        ax=df_yearly.groupby(['week_rotate'])['chl_rate_week'].mean().plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )
        ax.set_ylim(-12, 15)
        #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
        ax.set_yticks(np.arange(-12, 15, 2), )
        ax.set_xticks(np.arange(1, 25, 1))
        ax.legend(bbox_to_anchor=(1.15, 1.05))
        ax.set_xlabel("")
        ax.set_ylabel("")     
    return 0

start = year_min
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)    # The big subplot
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')

ax1 = fig.add_subplot(311)
plot_here(ax1, start)

start = start + 5
ax2 = fig.add_subplot(312)
plot_here(ax2, start)

start = start + 5
ax3 = fig.add_subplot(313)
plot_here(ax3, start)


ax.set_title("mean of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
ax.set_xlabel('week', fontsize=10)
ax.set_ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)


plt.savefig(str(freq)+"D_weekly_mean_" + str(i) +".pdf", orientation='landscape', )
plt.show()
plt.close()

plt.savefig?

# %%
### Part 1: Plot for the mean of the weekly trends
### Mean
### using subplots
# to be removed!!! not recommended!
# http://stackoverflow.com/questions/16150819/common-xlabel-ylabel-for-matplotlib-subplots

start = year_min
fig = plt.figure(figsize=(10,8))

for i in range(0,3):
    plt.subplot(311+i)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].mean().plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )
        axes1.set_ylim(-12, 15)
        #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
        axes1.set_yticks(np.arange(-12, 15, 2), )
        axes1.set_xticks(np.arange(1, 25, 1))
        axes1.legend(bbox_to_anchor=(1.15, 1.05))
        axes1.set_xlabel("")
        axes1.set_ylabel("")
        
    start = start + 5

fig.text(0.5, 0.04, 'week', fontsize=10, ha='center')
fig.text(0.04, 0.5, 'rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10, va='center', rotation='vertical')
fig.text(0.5, 0.92, "mean of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10, ha='center')
#plt.(...) cannot be used here


#plt.savefig(str(freq)+"D_weekly_mean_" + str(i) +".pdf")
plt.show()
plt.close()

# %%
### Part 2: Plot for the median of the weekly trends
### Median
start = year_min
for i in range(0,3):
    #plt.subplot(311+i)
    plt.figure(figsize=(8,6))
    plt.title("median of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].quantile(.50).plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )

    start = start + 4
    axes1.set_ylim(-10, 10)
    #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
    plt.xlabel('week', fontsize=10)
    plt.ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)
    plt.yticks(np.arange(-10, 10, 0.5))
    plt.xticks(np.arange(1, 25, 1))

    axes1.legend(bbox_to_anchor=(1.15, 1.05))
    #plt.savefig(str(freq)+"D_weekly_median_" + str(i) +".pdf")
    plt.show()  
    plt.close()

# %%
### Part 3: Plot for the 25% quantile of the weekly trends
### 25% quantile
start = year_min
for i in range(0,3):
    #plt.subplot(311+i)
    plt.figure(figsize=(8,6))
    plt.title("25% quantile of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].quantile(.25).plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )

    start = start + 4
    axes1.set_ylim(-10, 10)
    #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
    plt.xlabel('week', fontsize=10)
    plt.ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)
    plt.yticks(np.arange(-10, 10, 0.5))
    plt.xticks(np.arange(1, 25, 1))

    axes1.legend(bbox_to_anchor=(1.15, 1.05))
    #plt.savefig(str(freq)+"D_weekly_quantile(25)_" + str(i) +".pdf")
    plt.show()  
    plt.close()

# %%
### Part 4: Plot for the 75% quantile of the weekly trends
### 75% quantile
start = year_min
for i in range(0,3):
    #plt.subplot(311+i)
    plt.figure(figsize=(8,6))
    plt.title("75% of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].quantile(.75).plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )

    start = start + 4
    axes1.set_ylim(-10, 10)
    #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
    plt.xlabel('week', fontsize=10)
    plt.ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)
    plt.yticks(np.arange(-10, 10, 0.5))
    plt.xticks(np.arange(1, 25, 1))

    axes1.legend(bbox_to_anchor=(1.15, 1.05))
    #plt.savefig(str(freq)+"D_weekly_quantile(75)_" + str(i) +".pdf")
    plt.show()  
    plt.close()

# %%
#matplotlib.pyplot.close("all")
plt.close('all')
plt.cla()  # axis
plt.clf()  # figure
plt.show()
