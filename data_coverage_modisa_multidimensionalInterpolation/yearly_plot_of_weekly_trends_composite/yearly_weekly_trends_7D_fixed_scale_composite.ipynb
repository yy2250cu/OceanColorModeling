# %% [markdown]
# ## Composite Weekly trends plot for different years
# * resampling frequency is 7 Days
# * composition of the "Mean" and the "Median" of weekly trends for different years
# * various rates of the chlor-a concentration
# * "fixed scale" seems more illustrative than the "min-max scale"

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import xarray as xr
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime
import datetime

# %%
# load the floats data 
# ********************
# *** CSV files ***
# ********************
# load CSV output    
#plt = plt.figure(8,6)
plt.close('all')
plt.cla()  # axis
plt.clf()  # figure
plt.show()

freq = 7
pref = 'df_chl_dist_out_'
surf =  '_modisa.csv'
infile = pref + str(freq) + 'D' + surf

folder = '../data_collector_modisa_chla9km/df_multidimInterpolation/'
direc = folder + infile
direc

print('in_filename and path:', direc)

df_tmp = pd.read_csv(direc, index_col='index')
df_tmp.sort_values(['id', 'time'])[:20]
# Out:
# in_filename and path: ../data_collector_modisa_chla9km/df_multidimInterpolation/df_chl_dist_out_7D_modisa.csv
#              time     id         vn   var_lat        lon         ve   var_lon  \
# index
# 1      2002-11-07  10206   3.113143  0.000487  67.145571  -2.351607  0.001486
# 260    2002-11-14  10206   0.388071  0.001253  67.061143  -1.862964  0.004840
# 519    2002-11-21  10206   2.276107  0.000887  66.993786  -1.006821  0.003094
# 778    2002-11-28  10206   3.435071  0.000584  66.747107  -9.219786  0.001896
# 1037   2002-12-05  10206   8.209536  0.002856  66.037000 -13.890714  0.012162
# 1296   2002-12-12  10206   6.536571  0.000794  65.378643  -9.293893  0.002709
# 1555   2002-12-19  10206   4.508357  0.001232  64.930429  -8.125214  0.004582
# 1814   2002-12-26  10206  -0.180321  0.000485  64.403250 -10.488286  0.001438
# 2073   2003-01-02  10206  -5.279500  0.000585  63.779821 -11.877429  0.001830
# 2850   2003-01-23  10206  -8.000000  0.001094  62.146182  -9.878667  0.003847
# 3      2002-11-07  11089  -1.954857  0.000067  64.522214 -16.224571  0.000133
# 262    2002-11-14  11089 -14.241071  0.000061  63.432571 -27.037464  0.000115
# 521    2002-11-21  11089  -3.419321  0.000065  61.641464 -31.721679  0.000124
# 780    2002-11-28  11089  14.019036  0.000056  59.867107 -33.800607  0.000103
# 1039   2002-12-05  11089  29.248643  0.000052  58.768000   7.996536  0.000096
# 1298   2002-12-12  11089 -27.122714  0.000064  59.882893   5.714429  0.000123
# 1557   2002-12-19  11089  -1.449250  0.000062  59.142357 -19.138571  0.000119
# 1816   2002-12-26  11089  17.997464  0.000064  58.478500   0.788214  0.000122
# 2075   2003-01-02  11089 -15.477679  0.000064  58.956536  10.206107  0.000118
# 2334   2003-01-09  11089 -26.593429  0.000073  59.119536  -3.790536  0.000139
#
#             temp        lat      var_tmp     ...      chlor_a_log_e  chl_rate  \
# index                                        ...
# 1            NaN  11.112429  1000.000000     ...          -2.028820 -0.000298
# 260          NaN  11.168893  1000.000000     ...          -1.951339  0.001513
# 519          NaN  11.222714  1000.000000     ...          -2.017571 -0.001301
# 778          NaN  11.368571  1000.000000     ...          -1.963580  0.001054
# 1037         NaN  11.712321  1000.000000     ...          -1.950322  0.000268
# 1296         NaN  12.122571  1000.000000     ...          -2.026572 -0.001492
# 1555         NaN  12.417786  1000.000000     ...          -1.852013  0.003591
# 1814         NaN  12.569393  1000.000000     ...          -1.847456  0.000102
# 2073         NaN  12.380429  1000.000000     ...          -1.485008  0.009838
# 2850         NaN  11.137273  1000.000000     ...          -1.448402 -0.016926
# 3      28.931286  14.321929     0.003821     ...          -1.574467  0.011563
# 262    28.311250  13.867750     0.003591     ...          -1.502852  0.002197
# 521    28.014893  13.258036     0.003669     ...          -1.575510 -0.002228
# 780    27.794964  13.481036     0.003680     ...          -1.008412  0.022557
# 1039   27.217036  15.050929     0.003712     ...          -1.082738 -0.003733
# 1298   27.114286  14.928107     0.003629     ...          -1.167735 -0.003942
# 1557   27.090750  13.910857     0.003462     ...          -1.306461 -0.005756
# 1816   26.712964  14.595821     0.003560     ...          -1.197130  0.004469
# 2075   26.197143  14.797143     0.003778     ...          -1.355419 -0.006317
# 2334   25.976464  13.343857     0.003778     ...          -1.104923  0.010485
#
#        chl_log_e_rate  chl_rate_stand  chl_log_e_rate_stand  chl_rate_week  \
# index
# 1           -0.002245        0.016300             -0.003157      -0.002083
# 260          0.011069        0.020531              0.163681       0.010593
# 519         -0.009462        0.013957             -0.093583      -0.009106
# 778          0.007713        0.019458              0.121632       0.007377
# 1037         0.001894        0.017621              0.048714       0.001873
# 1296        -0.010893        0.013511             -0.111516      -0.010442
# 1555         0.024937        0.025384              0.337463       0.025134
# 1814         0.000651        0.017235              0.033138       0.000717
# 2073         0.051778        0.039978              0.673806       0.068863
# 2850        -0.058332       -0.022547             -0.705965      -0.118481
# 3            0.070802        0.044010              0.912187       0.080942
# 262          0.010231        0.022128              0.153180       0.015377
# 521         -0.010380        0.011792             -0.105086      -0.015593
# 780          0.081014        0.069693              1.040155       0.157896
# 1039        -0.010618        0.008274             -0.108073      -0.026131
# 1298        -0.012142        0.007785             -0.127174      -0.027596
# 1557        -0.019818        0.003547             -0.223356      -0.040294
# 1816         0.015619        0.027436              0.220696       0.031283
# 2075        -0.022613        0.002237             -0.258375      -0.044221
# 2334         0.035785        0.041492              0.473398       0.073397
#
#        chl_log_e_rate_week  week  week_rotate        dist
# index
# 1                -0.015718    45            2  540.280903
# 260               0.077481    46            3  549.401444
# 519              -0.066232    47            4  556.723597
# 778               0.053991    48            5  583.873795
# 1037              0.013258    49            6  663.256319
# 1296             -0.076250    50            7  739.327702
# 1555              0.174559    51            8  792.306625
# 1814              0.004557    52            9  851.584147
# 2073              0.362448     1           11  915.508533
# 2850             -0.408322     4           14  843.044253
# 3                 0.495613    45            2  879.998383
# 262               0.071615    46            3  823.860681
# 521              -0.072658    47            4  736.473865
# 780               0.567098    48            5  582.940458
# 1039             -0.074327    49            6  374.208004
# 1298             -0.084997    50            7  472.605572
# 1557             -0.138726    51            8  497.038929
# 1816              0.109331    52            9  393.659035
# 2075             -0.158289     1           11  408.585680
# 2334              0.250496     2           12  504.268293
#
# [20 rows x 22 columns]

# %%
df_tmp['time'] = pd.to_datetime(df_tmp['time']) # ,format='%m/%d/%y %I:%M%p'
df_timed = df_tmp.set_index('time')
# add a new column to the dataset
df_timed['year'] = df_timed.index.year
df_timed[:20]

year_max = df_timed.index.year.max()
year_min = df_timed.index.year.min()
print('year_max', year_max)
print('year_min', year_min)
#print(df_timed)
# Out:
# year_max 2016
# year_min 2002

# %%
### Part 1: Plot for the mean of the weekly trends
### Mean
start = year_min
for i in range(0,3):
    #plt.subplot(311+i)
    plt.figure(figsize=(8,6))
    plt.title("mean of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].mean().plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )

    start = start + 5
    axes1.set_ylim(-10, 10)
    #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
    plt.xlabel('week', fontsize=10)
    plt.ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)
    plt.yticks(np.arange(-12, 14, 2))
    plt.xticks(np.arange(1, 25, 1))

    axes1.legend(bbox_to_anchor=(1.15, 1.05))
    #plt.savefig(str(freq)+"D_weekly_mean_" + str(i) +".pdf")
    plt.show()
    
    plt.close()

# %%
### Part 1: Plot for the mean of the weekly trends
### Mean
### using subplots
# recommended approach
# http://stackoverflow.com/questions/6963035/pyplot-axes-labels-for-subplots

def plot_here(ax, start):
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        ax=df_yearly.groupby(['week_rotate'])['chl_rate_week'].mean().plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )
        ax.set_ylim(-12, 15)
        #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
        ax.set_yticks(np.arange(-12, 15, 2), )
        ax.set_xticks(np.arange(1, 25, 1))
        ax.legend(bbox_to_anchor=(1.15, 1.05))
        ax.set_xlabel("")
        ax.set_ylabel("")     
    return 0

start = year_min
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)    # The big subplot
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')

ax1 = fig.add_subplot(311)
plot_here(ax1, start)

start = start + 5
ax2 = fig.add_subplot(312)
plot_here(ax2, start)

start = start + 5
ax3 = fig.add_subplot(313)
plot_here(ax3, start)


ax.set_title("mean of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
ax.set_xlabel('week', fontsize=10)
ax.set_ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)


plt.savefig(str(freq)+"D_weekly_mean_" + str(i) +".pdf", orientation='landscape', )
plt.show()
plt.close()

# %%
### Part 1: Plot for the mean of the weekly trends
### Mean
### using subplots
# to be removed!!! not recommended!
# http://stackoverflow.com/questions/16150819/common-xlabel-ylabel-for-matplotlib-subplots

start = year_min
fig = plt.figure(figsize=(10,8))

for i in range(0,3):
    plt.subplot(311+i)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].mean().plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )
        axes1.set_ylim(-12, 15)
        #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
        axes1.set_yticks(np.arange(-12, 15, 2), )
        axes1.set_xticks(np.arange(1, 25, 1))
        axes1.legend(bbox_to_anchor=(1.15, 1.05))
        axes1.set_xlabel("")
        axes1.set_ylabel("")
        
    start = start + 5

fig.text(0.5, 0.04, 'week', fontsize=10, ha='center')
fig.text(0.04, 0.5, 'rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10, va='center', rotation='vertical')
fig.text(0.5, 0.92, "mean of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10, ha='center')
#plt.(...) cannot be used here


#plt.savefig(str(freq)+"D_weekly_mean_" + str(i) +".pdf")
plt.show()
plt.close()

# %%
### Part 2: Plot for the median of the weekly trends
### Median
start = year_min
for i in range(0,3):
    #plt.subplot(311+i)
    plt.figure(figsize=(8,6))
    plt.title("median of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].quantile(.50).plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )

    start = start + 4
    axes1.set_ylim(-10, 10)
    #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
    plt.xlabel('week', fontsize=10)
    plt.ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)
    plt.yticks(np.arange(-10, 10, 0.5))
    plt.xticks(np.arange(1, 25, 1))

    axes1.legend(bbox_to_anchor=(1.15, 1.05))
    #plt.savefig(str(freq)+"D_weekly_median_" + str(i) +".pdf")
    plt.show()  
    plt.close()

# %%
### Part 3: Plot for the 25% quantile of the weekly trends
### 25% quantile
start = year_min
for i in range(0,3):
    #plt.subplot(311+i)
    plt.figure(figsize=(8,6))
    plt.title("25% quantile of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].quantile(.25).plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )

    start = start + 4
    axes1.set_ylim(-10, 10)
    #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
    plt.xlabel('week', fontsize=10)
    plt.ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)
    plt.yticks(np.arange(-10, 10, 0.5))
    plt.xticks(np.arange(1, 25, 1))

    axes1.legend(bbox_to_anchor=(1.15, 1.05))
    #plt.savefig(str(freq)+"D_weekly_quantile(25)_" + str(i) +".pdf")
    plt.show()  
    plt.close()

# %%
### Part 4: Plot for the 75% quantile of the weekly trends
### 75% quantile
start = year_min
for i in range(0,3):
    #plt.subplot(311+i)
    plt.figure(figsize=(8,6))
    plt.title("75% of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].quantile(.75).plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )

    start = start + 4
    axes1.set_ylim(-10, 10)
    #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
    plt.xlabel('week', fontsize=10)
    plt.ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)
    plt.yticks(np.arange(-10, 10, 0.5))
    plt.xticks(np.arange(1, 25, 1))

    axes1.legend(bbox_to_anchor=(1.15, 1.05))
    #plt.savefig(str(freq)+"D_weekly_quantile(75)_" + str(i) +".pdf")
    plt.show()  
    plt.close()

# %%
#matplotlib.pyplot.close("all")
plt.close('all')
plt.cla()  # axis
plt.clf()  # figure
plt.show()
