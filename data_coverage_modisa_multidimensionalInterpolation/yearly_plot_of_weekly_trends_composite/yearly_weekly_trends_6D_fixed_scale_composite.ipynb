# %% [markdown]
# ## Composite Weekly trends plot for different years
# * resampling frequency is 6 Days
# * composition of the "Mean" and the "Median" of weekly trends for different years
# * various rates of the chlor-a concentration
# * "fixed scale" seems more illustrative than the "min-max scale"

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import xarray as xr
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime
import datetime

# %%
# load the floats data 
# ********************
# *** CSV files ***
# ********************
# load CSV output    
#plt = plt.figure(8,6)
plt.close('all')
plt.cla()  # axis
plt.clf()  # figure
plt.show()

freq = 6
pref = 'df_chl_dist_out_'
surf =  '_modisa.csv'
infile = pref + str(freq) + 'D' + surf

folder = '../data_collector_modisa_chla9km/df_multidimInterpolation/'
direc = folder + infile
direc

print('in_filename and path:', direc)

df_tmp = pd.read_csv(direc, index_col='index')
df_tmp.sort_values(['id', 'time'])[:20]
# Out:
# in_filename and path: ../data_collector_modisa_chla9km/df_multidimInterpolation/df_chl_dist_out_6D_modisa.csv
#              time     id        spd        lat      var_tmp        lon  \
# index
# 1      2002-11-01  10206  11.098375  10.819333  1000.000000  67.400875
# 260    2002-11-07  10206   6.336958  11.107000  1000.000000  67.149208
# 519    2002-11-13  10206   3.300667  11.167667  1000.000000  67.085542
# 778    2002-11-19  10206   4.575583  11.184417  1000.000000  67.007000
# 1037   2002-11-25  10206   4.905375  11.290292  1000.000000  66.939542
# 1296   2002-12-01  10206  14.679250  11.451333  1000.000000  66.529750
# 1555   2002-12-07  10206  15.284292  11.808250  1000.000000  65.874333
# 1814   2002-12-13  10206  11.345167  12.149792  1000.000000  65.338417
# 2073   2002-12-19  10206   9.457417  12.400000  1000.000000  64.962750
# 2332   2002-12-25  10206  10.702708  12.570500  1000.000000  64.529792
# 2591   2002-12-31  10206  13.410292  12.477292  1000.000000  64.004000
# 3368   2003-01-18  10206  13.985458  11.468583  1000.000000  62.485833
# 3627   2003-01-24  10206  13.179000  11.109556  1000.000000  62.110722
# 3      2002-11-01  11089  12.775208  14.236667     0.003775  65.187083
# 262    2002-11-07  11089  16.956875  14.336875     0.003873  64.589250
# 521    2002-11-13  11089  25.847125  14.022917     0.003512  63.741208
# 780    2002-11-19  11089  36.300458  13.385042     0.003717  62.282042
# 1039   2002-11-25  11089  31.933042  13.262250     0.003729  60.793583
# 1816   2002-12-13  11089  36.243458  14.818667     0.003704  59.947125
# 2075   2002-12-19  11089  23.774583  13.895708     0.003454  59.224833
#
#         var_lat   var_lon         vn       temp     ...      chlor_a_log_e  \
# index                                               ...
# 1      0.000411  0.001188   6.497542        NaN     ...          -2.018036
# 260    0.000476  0.001453   3.659208        NaN     ...          -2.028323
# 519    0.001513  0.005836   0.114500        NaN     ...          -1.959117
# 778    0.000303  0.000820   1.464125        NaN     ...          -1.949704
# 1037   0.000927  0.003302   2.750083        NaN     ...          -1.982345
# 1296   0.001004  0.003438   5.781167        NaN     ...          -2.055008
# 1555   0.003186  0.013777   7.853792        NaN     ...          -1.936423
# 1814   0.000596  0.001924   6.328708        NaN     ...          -2.027973
# 2073   0.001380  0.005184   4.927875        NaN     ...          -1.856796
# 2332   0.000500  0.001503   1.268083        NaN     ...          -1.743275
# 2591   0.000361  0.000999  -4.584875        NaN     ...          -1.547381
# 3368   0.001007  0.003529 -10.582167        NaN     ...          -1.093854
# 3627   0.000795  0.002644  -8.204294        NaN     ...          -1.387378
# 3      0.000057  0.000106   5.029292  28.979875     ...          -1.971267
# 262    0.000068  0.000133  -1.580333  28.978875     ...          -1.614688
# 521    0.000061  0.000116 -11.590250  28.424792     ...          -1.192585
# 780    0.000060  0.000112 -10.847542  28.016125     ...          -1.279864
# 1039   0.000063  0.000119   3.835042  27.994167     ...          -1.123332
# 1816   0.000063  0.000121 -29.562292  27.100708     ...          -1.103233
# 2075   0.000061  0.000118  -4.166000  27.107292     ...          -1.139391
#
#        chl_rate  chl_log_e_rate  chl_rate_stand  chl_log_e_rate_stand  \
# index
# 1     -0.000912       -0.006725        0.011220             -0.035324
# 260   -0.000227       -0.001715        0.012194              0.015978
# 519    0.001571        0.011534        0.014748              0.151635
# 778    0.000222        0.001569        0.012831              0.049598
# 1037  -0.000762       -0.005440        0.011433             -0.022170
# 1296  -0.001609       -0.012111        0.010230             -0.090469
# 1555   0.002688        0.019764        0.016334              0.235902
# 1814  -0.002103       -0.015258        0.009528             -0.122700
# 2073   0.004095        0.028530        0.018334              0.325652
# 2332   0.003129        0.018920        0.016961              0.227260
# 2591   0.006310        0.032649        0.021480              0.367833
# 3368   0.010336        0.034127        0.027200              0.382964
# 3627  -0.014199       -0.048921       -0.007658             -0.467374
# 3      0.001464        0.010855        0.014595              0.144684
# 262    0.009945        0.059430        0.026646              0.642047
# 521    0.017414        0.070351        0.037257              0.753867
# 780   -0.004227       -0.014547        0.006510             -0.115413
# 1039   0.007853        0.026089        0.023673              0.300660
# 1816  -0.008632       -0.024176        0.000251             -0.214010
# 2075  -0.001964       -0.006026        0.009725             -0.028173
#
#        chl_rate_week  chl_log_e_rate_week  week  week_rotate        dist
# index
# 1          -0.006385            -0.047074    44            1  514.131245
# 260        -0.001587            -0.012002    45            2  539.895835
# 519         0.010998             0.080740    46            3  546.738170
# 778         0.001556             0.010983    47            4  555.297392
# 1037       -0.005332            -0.038081    48            5  562.697149
# 1296       -0.011263            -0.084774    48            5  607.886217
# 1555        0.018815             0.138349    49            6  681.822087
# 1814       -0.014720            -0.106809    50            7  744.061720
# 2073        0.028665             0.199707    51            8  788.525719
# 2332        0.021903             0.132441    52            9  838.049455
# 2591        0.044168             0.228543     1           11  892.851498
# 3368        0.072349             0.238887     3           13  873.225205
# 3627       -0.099393            -0.342444     4           14  839.859117
# 3           0.010246             0.075988    44            1  813.033841
# 262         0.069618             0.416009    45            2  877.495924
# 521         0.121897             0.492454    46            3  836.456705
# 780        -0.029588            -0.101826    47            4  781.547937
# 1039        0.054973             0.182621    48            5  668.542501
# 1816       -0.060427            -0.169232    50            7  485.489370
# 2075       -0.013747            -0.042185    51            8  503.736070
#
# [20 rows x 22 columns]

# %%
df_tmp['time'] = pd.to_datetime(df_tmp['time']) # ,format='%m/%d/%y %I:%M%p'
df_timed = df_tmp.set_index('time')
# add a new column to the dataset
df_timed['year'] = df_timed.index.year
df_timed[:20]

year_max = df_timed.index.year.max()
year_min = df_timed.index.year.min()
print('year_max', year_max)
print('year_min', year_min)
#print(df_timed)
# Out:
# year_max 2016
# year_min 2002

# %%
### Part 1: Plot for the mean of the weekly trends
### Mean
start = year_min
for i in range(0,3):
    #plt.subplot(311+i)
    plt.figure(figsize=(8,6))
    plt.title("mean of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].mean().plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )

    start = start + 5
    axes1.set_ylim(-10, 10)
    #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
    plt.xlabel('week', fontsize=10)
    plt.ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)
    plt.yticks(np.arange(-12, 14, 2))
    plt.xticks(np.arange(1, 25, 1))

    axes1.legend(bbox_to_anchor=(1.15, 1.05))
    #plt.savefig(str(freq)+"D_weekly_mean_" + str(i) +".pdf")
    plt.show()
    
    plt.close()

# %%
### Part 1: Plot for the mean of the weekly trends
### Mean
### using subplots
# recommended approach
# http://stackoverflow.com/questions/6963035/pyplot-axes-labels-for-subplots

def plot_here(ax, start):
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        ax=df_yearly.groupby(['week_rotate'])['chl_rate_week'].mean().plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )
        ax.set_ylim(-12, 15)
        #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
        ax.set_yticks(np.arange(-12, 15, 2), )
        ax.set_xticks(np.arange(1, 25, 1))
        ax.legend(bbox_to_anchor=(1.15, 1.05))
        ax.set_xlabel("")
        ax.set_ylabel("")     
    return 0

start = year_min
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)    # The big subplot
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')

ax1 = fig.add_subplot(311)
plot_here(ax1, start)

start = start + 5
ax2 = fig.add_subplot(312)
plot_here(ax2, start)

start = start + 5
ax3 = fig.add_subplot(313)
plot_here(ax3, start)


ax.set_title("mean of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
ax.set_xlabel('week', fontsize=10)
ax.set_ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)


plt.savefig(str(freq)+"D_weekly_mean_" + str(i) +".pdf", orientation='landscape', )
plt.show()
plt.close()

# %%
### Part 1: Plot for the mean of the weekly trends
### Mean
### using subplots
# to be removed!!! not recommended!
# http://stackoverflow.com/questions/16150819/common-xlabel-ylabel-for-matplotlib-subplots

start = year_min
fig = plt.figure(figsize=(10,8))

for i in range(0,3):
    plt.subplot(311+i)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].mean().plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )
        axes1.set_ylim(-12, 15)
        #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
        axes1.set_yticks(np.arange(-12, 15, 2), )
        axes1.set_xticks(np.arange(1, 25, 1))
        axes1.legend(bbox_to_anchor=(1.15, 1.05))
        axes1.set_xlabel("")
        axes1.set_ylabel("")
        
    start = start + 5

fig.text(0.5, 0.04, 'week', fontsize=10, ha='center')
fig.text(0.04, 0.5, 'rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10, va='center', rotation='vertical')
fig.text(0.5, 0.92, "mean of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10, ha='center')
#plt.(...) cannot be used here


#plt.savefig(str(freq)+"D_weekly_mean_" + str(i) +".pdf")
plt.show()
plt.close()

# %%
### Part 2: Plot for the median of the weekly trends
### Median
start = year_min
for i in range(0,3):
    #plt.subplot(311+i)
    plt.figure(figsize=(8,6))
    plt.title("median of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].quantile(.50).plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )

    start = start + 4
    axes1.set_ylim(-10, 10)
    #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
    plt.xlabel('week', fontsize=10)
    plt.ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)
    plt.yticks(np.arange(-10, 10, 0.5))
    plt.xticks(np.arange(1, 25, 1))

    axes1.legend(bbox_to_anchor=(1.15, 1.05))
    #plt.savefig(str(freq)+"D_weekly_median_" + str(i) +".pdf")
    plt.show()  
    plt.close()

# %%
### Part 3: Plot for the 25% quantile of the weekly trends
### 25% quantile
start = year_min
for i in range(0,3):
    #plt.subplot(311+i)
    plt.figure(figsize=(8,6))
    plt.title("25% quantile of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].quantile(.25).plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )

    start = start + 4
    axes1.set_ylim(-10, 10)
    #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
    plt.xlabel('week', fontsize=10)
    plt.ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)
    plt.yticks(np.arange(-10, 10, 0.5))
    plt.xticks(np.arange(1, 25, 1))

    axes1.legend(bbox_to_anchor=(1.15, 1.05))
    #plt.savefig(str(freq)+"D_weekly_quantile(25)_" + str(i) +".pdf")
    plt.show()  
    plt.close()

# %%
### Part 4: Plot for the 75% quantile of the weekly trends
### 75% quantile
start = year_min
for i in range(0,3):
    #plt.subplot(311+i)
    plt.figure(figsize=(8,6))
    plt.title("75% of the weekly binned Lagrangian rate of change of Chl-a", fontsize=10)
    for current_year in range(start, start+5):
        mask = df_timed.year == current_year
        df_yearly = df_timed[mask]
        #print('\n summary statistics of chl_rate_week for the year %d \n' % (current_year) )
        #print(df_yearly.chl_rate_week.describe())
        axes1=df_yearly.groupby(['week_rotate'])['chl_rate_week'].quantile(.75).plot(linestyle="-", linewidth=0.8,  label='%d' % current_year  )

    start = start + 4
    axes1.set_ylim(-10, 10)
    #axes1.set_title("Year " + str(current_year) + ": Line plot of the weekly data on the rate of change per week of the $Chl_a$ Concentration",  fontsize=10)
    plt.xlabel('week', fontsize=10)
    plt.ylabel('rate of change of the $Chl_a$ in $mg/(m^3 \cdot 7days)$', fontsize=10)
    plt.yticks(np.arange(-10, 10, 0.5))
    plt.xticks(np.arange(1, 25, 1))

    axes1.legend(bbox_to_anchor=(1.15, 1.05))
    #plt.savefig(str(freq)+"D_weekly_quantile(75)_" + str(i) +".pdf")
    plt.show()  
    plt.close()

# %%
#matplotlib.pyplot.close("all")
plt.close('all')
plt.cla()  # axis
plt.clf()  # figure
plt.show()
